# %%
#Import Libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
#Create a file path
path= r'C:\Users\Zinnia\Documents\Career Foundry Data Analytics Course\Achievement 6\Data\Edited'

# %%
#Import Data
df=pd.read_pickle(os.path.join(path, 'merged_edited_data.pkl'))

# %%
#Check matplotlib version
matplotlib.__version__
# Out:
# '3.4.3'

# %%
#Doing this to ensur the charts are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %% [markdown]
# # Check and Clean Data

# %%
#Check the shape
df.shape
# Out:
# (9094, 16)

# %%
#Look at column names
df.columns
# Out:
# Index(['County_x', 'Municipality', '2019: Area', '2021: Area',
#        '2019: Census Population', '2021: Census Population', '2020: Workforce',
#        '2020: % Unemployed', '2017: Average Residential Property Value ($)',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'County_y', 'Total_Acres', '_merge'],
#       dtype='object')

# %%
#Rename upper case columns
df.rename(columns={'OBJECTID' : 'Object_Id', 'COUNTY' : 'County', 'MUN_NUM' : 'Municipal_Num', 'LOT_NUM' : 'Lot_Num', 'GIS_ACRES' : 'GIS_Acres', 'MANAGE_TYPE' : 'Manage_Type', 'MANAGED_BY' : 'Managed_By', 'OWNER_TYPE' : 'Owner_Type', 'OWNER' : 'Owner', 'FUNDING_TYPE' : 'Funding_Type', 'ENCUMBRANCE_STATUS' : 'Encumbrance_Status', 'FEE_SIMPLE_NAME' : 'Property_Name'}, inplace = True)

# %%
#Check updated columns
df.columns
# Out:
# Index(['County_x', 'Municipality', '2019: Area', '2021: Area',
#        '2019: Census Population', '2021: Census Population', '2020: Workforce',
#        '2020: % Unemployed', '2017: Average Residential Property Value ($)',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'County_y', 'Total_Acres', '_merge'],
#       dtype='object')

# %%
df.head()
# Out:
#    County_x   Municipality  2019: Area  2021: Area  2019: Census Population  \
# 0  Atlantic        Absecon        5.40        5.47                     8411
# 1  Atlantic  Atlantic City       10.75       10.76                    39558
# 2  Atlantic  Atlantic City       10.75       10.76                    39558
# 3  Atlantic  Atlantic City       10.75       10.76                    39558
# 4  Atlantic  Atlantic City       10.75       10.76                    39558
#
#    2021: Census Population  2020: Workforce  2020: % Unemployed  \
# 0                     9137             4437               17.33
# 1                    38497            15995               25.71
# 2                    38497            15995               25.71
# 3                    38497            15995               25.71
# 4                    38497            15995               25.71
#
#    2017: Average Residential Property Value ($)  \
# 0                                      176556.0
# 1                                      127451.0
# 2                                      127451.0
# 3                                      127451.0
# 4                                      127451.0
#
#    2020: Average Residential Property Value ($)  \
# 0                                      170824.0
# 1                                      144901.0
# 2                                      144901.0
# 3                                      144901.0
# 4                                      144901.0
#
#    2020: Municipal Budget per Capita ($)  2018: % Democrats  \
# 0                                   1240              29.76
# 1                                   5609              94.97
# 2                                   5609              94.97
# 3                                   5609              94.97
# 4                                   5609              94.97
#
#    2018: % Republicans  County_y  Total_Acres     _merge
# 0                28.89       NaN          NaN  left_only
# 1                 9.41  Atlantic   941.670537       both
# 2                 9.41  Atlantic   941.670537       both
# 3                 9.41  Atlantic   941.670537       both
# 4                 9.41  Atlantic   941.670537       both

# %%
#Check for duplicates
df[df.duplicated()]
# Out:
#        County_x       Municipality  2019: Area  2021: Area  \
# 2      Atlantic      Atlantic City       10.75       10.76
# 3      Atlantic      Atlantic City       10.75       10.76
# 4      Atlantic      Atlantic City       10.75       10.76
# 5      Atlantic      Atlantic City       10.75       10.76
# 6      Atlantic      Atlantic City       10.75       10.76
# ...         ...                ...         ...         ...
# 8830  Middlesex  Middlesex Borough        3.52        3.49
# 8831  Middlesex  Middlesex Borough        3.52        3.49
# 8832  Middlesex  Middlesex Borough        3.52        3.49
# 8833  Middlesex  Middlesex Borough        3.52        3.49
# 8834  Middlesex  Middlesex Borough        3.52        3.49
#
#       2019: Census Population  2021: Census Population  2020: Workforce  \
# 2                       39558                    38497            15995
# 3                       39558                    38497            15995
# 4                       39558                    38497            15995
# 5                       39558                    38497            15995
# 6                       39558                    38497            15995
# ...                       ...                      ...              ...
# 8830                    13635                    14636             7689
# 8831                    13635                    14636             7689
# 8832                    13635                    14636             7689
# 8833                    13635                    14636             7689
# 8834                    13635                    14636             7689
#
#       2020: % Unemployed  2017: Average Residential Property Value ($)  \
# 2                  25.71                                      127451.0
# 3                  25.71                                      127451.0
# 4                  25.71                                      127451.0
# 5                  25.71                                      127451.0
# 6                  25.71                                      127451.0
# ...                  ...                                           ...
# 8830               10.08                                      278609.0
# 8831               10.08                                      278609.0
# 8832               10.08                                      278609.0
# 8833               10.08                                      278609.0
# 8834               10.08                                      278609.0
#
#       2020: Average Residential Property Value ($)  \
# 2                                         144901.0
# 3                                         144901.0
# 4                                         144901.0
# 5                                         144901.0
# 6                                         144901.0
# ...                                            ...
# 8830                                      354335.0
# 8831                                      354335.0
# 8832                                      354335.0
# 8833                                      354335.0
# 8834                                      354335.0
#
#       2020: Municipal Budget per Capita ($)  2018: % Democrats  \
# 2                                      5609              94.97
# 3                                      5609              94.97
# 4                                      5609              94.97
# 5                                      5609              94.97
# 6                                      5609              94.97
# ...                                     ...                ...
# 8830                                   1546              30.69
# 8831                                   1546              30.69
# 8832                                   1546              30.69
# 8833                                   1546              30.69
# 8834                                   1546              30.69
#
#       2018: % Republicans   County_y  Total_Acres _merge
# 2                    9.41   Atlantic   941.670537   both
# 3                    9.41   Atlantic   941.670537   both
# 4                    9.41   Atlantic   941.670537   both
# 5                    9.41   Atlantic   941.670537   both
# 6                    9.41   Atlantic   941.670537   both
# ...                   ...        ...          ...    ...
# 8830                22.77  Middlesex   186.418222   both
# 8831                22.77  Middlesex   186.418222   both
# 8832                22.77  Middlesex   186.418222   both
# 8833                22.77  Middlesex   186.418222   both
# 8834                22.77  Middlesex   186.418222   both
#
# [8529 rows x 16 columns]

# %%
#Check for missing values
df.isnull().sum()
# Out:
# County_x                                          0
# Municipality                                      0
# 2019: Area                                        0
# 2021: Area                                        0
# 2019: Census Population                           0
# 2021: Census Population                           0
# 2020: Workforce                                   0
# 2020: % Unemployed                                0
# 2017: Average Residential Property Value ($)      1
# 2020: Average Residential Property Value ($)      1
# 2020: Municipal Budget per Capita ($)             0
# 2018: % Democrats                                 0
# 2018: % Republicans                               0
# County_y                                        554
# Total_Acres                                     554
# _merge                                            0
# dtype: int64

# %%
#Mixed type data check
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
# Out:
# County_y

# %%
df.columns
# Out:
# Index(['County_x', 'Municipality', '2019: Area', '2021: Area',
#        '2019: Census Population', '2021: Census Population', '2020: Workforce',
#        '2020: % Unemployed', '2017: Average Residential Property Value ($)',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'County_y', 'Total_Acres', '_merge'],
#       dtype='object')

# %%
#Check for missing values
df.isnull().sum()
# Out:
# County_x                                          0
# Municipality                                      0
# 2019: Area                                        0
# 2021: Area                                        0
# 2019: Census Population                           0
# 2021: Census Population                           0
# 2020: Workforce                                   0
# 2020: % Unemployed                                0
# 2017: Average Residential Property Value ($)      1
# 2020: Average Residential Property Value ($)      1
# 2020: Municipal Budget per Capita ($)             0
# 2018: % Democrats                                 0
# 2018: % Republicans                               0
# County_y                                        554
# Total_Acres                                     554
# _merge                                            0
# dtype: int64

# %%
#Drop columns
df = df.drop(columns = ['_merge'])

# %%
df = df.drop(columns = ['County_y'])

# %%
df.columns
# Out:
# Index(['County_x', 'Municipality', '2019: Area', '2021: Area',
#        '2019: Census Population', '2021: Census Population', '2020: Workforce',
#        '2020: % Unemployed', '2017: Average Residential Property Value ($)',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'Total_Acres'],
#       dtype='object')

# %%
#Check data types
df.dtypes
# Out:
# County_x                                         object
# Municipality                                     object
# 2019: Area                                      float64
# 2021: Area                                      float64
# 2019: Census Population                           int64
# 2021: Census Population                           int64
# 2020: Workforce                                   int64
# 2020: % Unemployed                              float64
# 2017: Average Residential Property Value ($)    float64
# 2020: Average Residential Property Value ($)    float64
# 2020: Municipal Budget per Capita ($)             int64
# 2018: % Democrats                               float64
# 2018: % Republicans                             float64
# Total_Acres                                     float64
# dtype: object

# %%
#check for mixed data types
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
df['Municipality'] = df['Municipality'].astype('str')

# %%
df['County_x'] = df['County_x'].astype('str')

# %%
df = df.drop(columns = ['2019: Census Population'])

# %%
df = df.drop(columns = ['2017: Average Residential Property Value ($)'])

# %%
df = df.drop(columns = ['2019: Area'])

# %%
df.columns
# Out:
# Index(['County_x', 'Municipality', '2021: Area', '2021: Census Population',
#        '2020: Workforce', '2020: % Unemployed',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'Total_Acres'],
#       dtype='object')

# %% [markdown]
# # Look for Correlations in the Data

# %%
df.corr()
# Out:
#                                               2021: Area  \
# 2021: Area                                      1.000000
# 2021: Census Population                        -0.018251
# 2020: Workforce                                -0.016420
# 2020: % Unemployed                              0.211766
# 2020: Average Residential Property Value ($)   -0.693275
# 2020: Municipal Budget per Capita ($)          -0.726820
# 2018: % Democrats                              -0.221256
# 2018: % Republicans                            -0.060166
# Total_Acres                                     0.987816
#
#                                               2021: Census Population  \
# 2021: Area                                                  -0.018251
# 2021: Census Population                                      1.000000
# 2020: Workforce                                              0.998983
# 2020: % Unemployed                                           0.096799
# 2020: Average Residential Property Value ($)                -0.118126
# 2020: Municipal Budget per Capita ($)                       -0.282093
# 2018: % Democrats                                            0.407536
# 2018: % Republicans                                         -0.582265
# Total_Acres                                                 -0.084697
#
#                                               2020: Workforce  \
# 2021: Area                                          -0.016420
# 2021: Census Population                              0.998983
# 2020: Workforce                                      1.000000
# 2020: % Unemployed                                   0.077346
# 2020: Average Residential Property Value ($)        -0.117357
# 2020: Municipal Budget per Capita ($)               -0.289494
# 2018: % Democrats                                    0.388590
# 2018: % Republicans                                 -0.571325
# Total_Acres                                         -0.080597
#
#                                               2020: % Unemployed  \
# 2021: Area                                              0.211766
# 2021: Census Population                                 0.096799
# 2020: Workforce                                         0.077346
# 2020: % Unemployed                                      1.000000
# 2020: Average Residential Property Value ($)           -0.578510
# 2020: Municipal Budget per Capita ($)                  -0.307489
# 2018: % Democrats                                       0.695227
# 2018: % Republicans                                    -0.604636
# Total_Acres                                             0.086585
#
#                                               2020: Average Residential Property Value ($)  \
# 2021: Area                                                                       -0.693275
# 2021: Census Population                                                          -0.118126
# 2020: Workforce                                                                  -0.117357
# 2020: % Unemployed                                                               -0.578510
# 2020: Average Residential Property Value ($)                                      1.000000
# 2020: Municipal Budget per Capita ($)                                             0.847222
# 2018: % Democrats                                                                -0.267354
# 2018: % Republicans                                                               0.521033
# Total_Acres                                                                      -0.682342
#
#                                               2020: Municipal Budget per Capita ($)  \
# 2021: Area                                                                -0.726820
# 2021: Census Population                                                   -0.282093
# 2020: Workforce                                                           -0.289494
# 2020: % Unemployed                                                        -0.307489
# 2020: Average Residential Property Value ($)                               0.847222
# 2020: Municipal Budget per Capita ($)                                      1.000000
# 2018: % Democrats                                                         -0.066933
# 2018: % Republicans                                                        0.483259
# Total_Acres                                                               -0.737170
#
#                                               2018: % Democrats  \
# 2021: Area                                            -0.221256
# 2021: Census Population                                0.407536
# 2020: Workforce                                        0.388590
# 2020: % Unemployed                                     0.695227
# 2020: Average Residential Property Value ($)          -0.267354
# 2020: Municipal Budget per Capita ($)                 -0.066933
# 2018: % Democrats                                      1.000000
# 2018: % Republicans                                   -0.805844
# Total_Acres                                           -0.281441
#
#                                               2018: % Republicans  Total_Acres
# 2021: Area                                              -0.060166     0.987816
# 2021: Census Population                                 -0.582265    -0.084697
# 2020: Workforce                                         -0.571325    -0.080597
# 2020: % Unemployed                                      -0.604636     0.086585
# 2020: Average Residential Property Value ($)             0.521033    -0.682342
# 2020: Municipal Budget per Capita ($)                    0.483259    -0.737170
# 2018: % Democrats                                       -0.805844    -0.281441
# 2018: % Republicans                                      1.000000    -0.009406
# Total_Acres                                             -0.009406     1.000000

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(10,10)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=8, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=12) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #I am not sure why my acreage is showing up in the table but not on the heat map. The tick marks also seem to be in the wrong place compared to the column labels.
# I find it interesting that I have yellow squares in the corner (total acres/county) as well as the expected ones in the middle.
#
# The workforce/unemployment is the highest correlation after the yellow squares.
#
# There's also a high property value/population correlation.
#
# Avg Property values/Municipality is another around 50%.
#
# Avg property values/Area was another.
#
# % Unemployed/Republicans was another and workforce/republicans.
#
# Democrats/Municipality and Democrats/Area appear to have a correlation.
#
# Unfortunately can't make a scatterplot for categorical variables so some of these can't be visuaized below.

# %% [markdown]
# # Scatter Plots

# %%
df.columns
# Out:
# Index(['County_x', 'Municipality', '2021: Area', '2021: Census Population',
#        '2020: Workforce', '2020: % Unemployed',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'Total_Acres'],
#       dtype='object')

# %%
# Create a scatterplot 

sns.lmplot(x = '2020: Workforce', y = '2020: % Unemployed', data = df)

# %% [markdown]
# #The data shows a cluster where a lower workforce population and unemployment are both typically low. A few outliers skew this to be a positive correlation but there is not a linear interdependence

# %%
# Create a scatterplot 

sns.lmplot(x = '2020: Average Residential Property Value ($)', y = '2021: Census Population', data = df)

# %% [markdown]
# #This graph is unusual. Most property values are low and the population is low. There are a few outliers with large populations in low value areas and with high values in low population areas. The line of best fit is negative and overall there doesn't appear to be linear interdependence.

# %% [markdown]
# # Pair Plots

# %%
# Create a subset 

sub = df[['County_x', 'Municipality', 'Total_Acres', '2021: Area', '2021: Census Population']]

# %%
# Create a pair plot 

g = sns.pairplot(sub)

# %%
sub2= df[['County_x', 'Municipality', '2021: Area', '2021: Census Population',
       '2020: Workforce', '2020: % Unemployed',
       '2020: Average Residential Property Value ($)',
       '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
       '2018: % Republicans', 'Total_Acres']]

# %%
# Create a pair plot 

g2 = sns.pairplot(sub2)

# %% [markdown]
# Variables to explore further:
# Area and Total Acres- Seems to show positive correlation. More acres preserved when more is available?
# Municipal Budget and Area- Its almost a straight line minus a few outliers

# %% [markdown]
# # Categorical Plot

# %%
df.columns
# Out:
# Index(['County_x', 'Municipality', '2021: Area', '2021: Census Population',
#        '2020: Workforce', '2020: % Unemployed',
#        '2020: Average Residential Property Value ($)',
#        '2020: Municipal Budget per Capita ($)', '2018: % Democrats',
#        '2018: % Republicans', 'Total_Acres'],
#       dtype='object')

# %%
sns.histplot(df['Total_Acres'], bins = 50, kde = True)
# Out:
# <AxesSubplot:xlabel='Total_Acres', ylabel='Count'>

# %%
df.loc[df['Total_Acres'] < 20, 'Acres'] = 'Low Acreage'
df.loc[(df['Total_Acres'] >= 20) & (df['Total_Acres'] < 50), 'Acres'] = 'Medium Acreage'
df.loc[df['Total_Acres'] >= 50, 'Acres'] = 'Large Acreage'

# %%
df['Total_Acres'].value_counts(dropna = False)
# Out:
# 664.751013      2176
# 18097.595963    2135
# 5908.156593     1285
# 17795.717698    1176
# 1958.210941      987
# NaN              554
# 941.670537       357
# 1699.569199      225
# 186.418222        80
# 66.002698         72
# 23.285549         25
# 3892.985708       22
# Name: Total_Acres, dtype: int64

# %%
# Create a categorical plot in seaborn

sns.set(style="ticks")
g = sns.catplot(x="2021: Area", y="Total_Acres", hue="Acres", data=df)

# %% [markdown]
# #Interestingly, no small acreage came up at all which is good for new jersey citizens. Some places with large area have conserved a large amount of acreage but the typical amount of total acreage skews lower and is more common in municipalities with smaller total area.

# %% [markdown]
# # Revisit Exploratory Questions
# Does the area of the municipality correlate to the area of preserved open space? Not strongly. Smaller area does show smaller preserved acreage but three is a lot of variability for municiaplities with a small area and there isn't a linear interdependence.
#
# Does the size of the population correlate to the amount of preserved open space? No
#
# Is unemployment rate correlated to the amount of preserved open space? No
#
# Do communities with different political views have significant differences in open space? Communities with more Republicans seem to have slightly more.
#
# Is open space related to average property values? No, areas with low total acreage preserved can still have high property values (other variables like acccess to businesses and transit may be related to this)

# %% [markdown]
# # Hypothesis
#
# Unfortunately my data isn't showing any significant correlations.
#
# Are more acres of open space preserved in municipalities with more area?
# Can a low budget be a limitation for not preserving open space?

# %%
df_2= df.drop_duplicates()

# %%
df_2.shape
# Out:
# (565, 12)

# %%
#Export to excel
df_2.to_csv((r'C:\Users\Zinnia\Documents\Career Foundry Data Analytics Course\Achievement 6\Data\Edited\Edited_Rutgers_Data_July_31.csv'))
