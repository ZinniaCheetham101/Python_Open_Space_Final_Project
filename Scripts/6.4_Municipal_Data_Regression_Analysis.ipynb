# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Code to display graphs in the notebook
# %matplotlib inline

# %%
#Create a file path
path= r'C:\Users\Zinnia\Documents\Career Foundry Data Analytics Course\Achievement 6\Data\Edited 8_13_22'

# %%
#Import Data
df=pd.read_csv(os.path.join(path, 'Edited_Open_Space_Municipal_with_Total_Acres.csv'), index_col=False)

# %% [markdown]
# #Data checks and cleaning

# %%
df.columns
# Out:
# Index(['County', 'Municipality', 'Total_Acres_Open_Space', 'Total SQ MI',
#        'Total Acres'],
#       dtype='object')

# %%
df.head()
# Out:
#      County          Municipality  Total_Acres_Open_Space  Total SQ MI  \
# 0  Atlantic          Absecon City              390.772836        5.468
# 1  Atlantic         Atlantic City              941.670537       10.760
# 2  Atlantic       Brigantine City             3116.170626        6.522
# 3  Atlantic         Buena Borough              309.927139        7.573
# 4  Atlantic  Buena Vista Township             2779.443567       41.080
#
#    Total Acres
# 0      3499.52
# 1      6886.40
# 2      4174.08
# 3      4846.72
# 4     26291.20

# %%
df.shape
# Out:
# (550, 5)

# %%
# Check for missing values

df.isnull().sum()
# Out:
# County                     0
# Municipality               0
# Total_Acres_Open_Space     0
# Total SQ MI               12
# Total Acres                0
# dtype: int64

# %% [markdown]
# #No missing values found

# %%
#Check for duplicates
dups = df.duplicated()

# %%
dups.shape
# Out:
# (550,)

# %% [markdown]
# #No duplicates found

# %%
#Check for extreme values
sns.histplot(df['Total_Acres_Open_Space'], bins=25)
# Out:
# <AxesSubplot:xlabel='Total_Acres_Open_Space', ylabel='Count'>

# %% [markdown]
# #This shows that most individual municipalities have a low acreage of open space and very few have large amounts.

# %%
#More data checks
df['Total_Acres_Open_Space'].mean()
# Out:
# 2054.1217082328562

# %%
df['Total_Acres_Open_Space'].median()
# Out:
# 234.92715285

# %%
df['Total_Acres_Open_Space'].max()
# Out:
# 59549.23301

# %%
df['Total_Acres_Open_Space'].min()
# Out:
# 0.0

# %%
df.columns
# Out:
# Index(['County', 'Municipality', 'Total_Acres_Open_Space', 'Total SQ MI',
#        'Total Acres'],
#       dtype='object')

# %% [markdown]
# #My hypothesis is that there is a positive correlation between the total acres in the county/municipality and the amount of preserved open space in the county/municipality

# %% [markdown]
# ## Regression Analysis

# %%
#Create a satterplot

df.plot(x = 'Total Acres', y='Total_Acres_Open_Space',style='o')
plt.title('County Acreage vs Total Acres of Open Space in the County')  
plt.xlabel('Total Acres')  
plt.ylabel('Acres of Preserved Open Space')  
plt.show()

# %% [markdown]
# #This is already interesting! I can see a positive correlation between my variables at last! There are a few more outliers at the municipal level than at the county level.

# %%
#Put the variables into NumPy arrays as objects

X = df['Total Acres'].values.reshape(-1,1)
y = df['Total_Acres_Open_Space'].values.reshape(-1,1)

# %%
X
# Out:
# array([[3.499520e+03],
#        [6.886400e+03],
#        [4.174080e+03],
#        [4.846720e+03],
#        [2.629120e+04],
#        [4.926080e+03],
#        [6.944640e+03],
#        [4.291008e+04],
#        [3.416768e+04],
#        [5.288960e+03],
#        [5.674752e+04],
#        [2.607936e+04],
#        [2.439040e+03],
#        [2.528000e+02],
#        [9.062400e+02],
#        [3.608000e+04],
#        [2.292480e+03],
#        [3.661440e+03],
#        [4.775680e+03],
#        [2.566400e+03],
#        [1.251200e+03],
#        [7.566080e+03],
#        [1.982080e+03],
#        [4.096640e+03],
#        [1.858560e+03],
#        [4.832000e+02],
#        [2.526080e+03],
#        [6.118400e+02],
#        [2.022400e+03],
#        [1.321600e+03],
#        [1.326080e+03],
#        [1.247360e+03],
#        [2.375680e+03],
#        [6.214400e+02],
#        [1.691520e+03],
#        [1.427840e+03],
#        [3.152000e+03],
#        [1.360640e+03],
#        [3.286400e+03],
#        [5.401600e+02],
#        [1.611520e+03],
#        [6.024960e+03],
#        [1.351040e+03],
#        [1.729920e+03],
#        [2.682240e+03],
#        [1.181440e+03],
#        [9.792000e+02],
#        [1.239680e+03],
#        [1.857280e+03],
#        [1.112960e+03],
#        [9.747200e+02],
#        [9.452800e+02],
#        [1.454080e+03],
#        [2.933760e+03],
#        [1.625088e+04],
#        [8.236800e+02],
#        [1.005440e+03],
#        [2.574720e+03],
#        [1.107200e+03],
#        [1.461120e+03],
#        [1.589760e+03],
#        [8.096000e+02],
#        [1.782400e+03],
#        [5.441280e+03],
#        [2.121600e+03],
#        [1.543040e+03],
#        [7.929600e+02],
#        [6.684800e+03],
#        [1.668480e+03],
#        [3.521920e+03],
#        [1.627520e+03],
#        [1.091200e+03],
#        [3.674880e+03],
#        [1.173120e+03],
#        [2.604800e+03],
#        [6.342400e+02],
#        [6.419200e+02],
#        [1.779840e+03],
#        [1.722880e+03],
#        [3.146240e+03],
#        [4.588800e+02],
#        [3.866240e+03],
#        [2.935040e+03],
#        [7.104000e+02],
#        [3.361920e+03],
#        [1.309440e+03],
#        [6.361600e+02],
#        [2.631616e+04],
#        [1.445760e+03],
#        [2.160640e+03],
#        [1.008000e+03],
#        [4.228480e+03],
#        [4.807936e+04],
#        [4.864000e+02],
#        [5.984000e+02],
#        [5.544320e+03],
#        [1.942400e+03],
#        [8.624640e+03],
#        [1.363904e+04],
#        [4.751360e+03],
#        [1.509120e+03],
#        [4.243200e+03],
#        [3.667200e+03],
#        [1.868160e+03],
#        [1.865984e+04],
#        [1.785600e+02],
#        [6.252160e+03],
#        [4.140800e+03],
#        [8.243840e+03],
#        [2.449280e+03],
#        [8.128000e+02],
#        [2.483136e+04],
#        [9.426560e+03],
#        [1.807360e+03],
#        [1.390336e+04],
#        [1.429376e+04],
#        [1.111552e+04],
#        [1.183360e+03],
#        [3.776000e+02],
#        [3.939584e+04],
#        [9.497600e+02],
#        [4.236800e+02],
#        [2.844928e+04],
#        [2.813248e+04],
#        [3.148928e+04],
#        [2.954880e+04],
#        [7.023360e+03],
#        [4.944000e+03],
#        [5.928832e+04],
#        [4.218240e+03],
#        [9.484800e+02],
#        [1.088000e+02],
#        [1.011840e+03],
#        [1.909760e+03],
#        [2.300160e+03],
#        [2.138880e+03],
#        [3.123200e+02],
#        [5.709440e+03],
#        [1.540608e+04],
#        [1.097600e+03],
#        [1.211520e+03],
#        [1.171200e+03],
#        [1.377280e+03],
#        [1.481600e+03],
#        [1.469056e+04],
#        [1.002240e+03],
#        [1.722880e+03],
#        [1.789440e+03],
#        [1.472000e+02],
#        [2.886400e+02],
#        [9.152000e+02],
#        [2.497280e+03],
#        [6.259200e+02],
#        [3.795200e+02],
#        [5.657600e+02],
#        [4.012800e+02],
#        [6.706560e+03],
#        [3.114240e+03],
#        [6.230000e+02],
#        [1.312640e+03],
#        [8.908800e+02],
#        [1.004800e+03],
#        [1.792000e+02],
#        [7.341440e+03],
#        [2.304128e+04],
#        [3.674688e+04],
#        [1.395200e+02],
#        [2.732800e+03],
#        [1.582720e+03],
#        [1.888000e+02],
#        [3.866944e+04],
#        [1.752192e+04],
#        [4.495232e+04],
#        [1.104000e+03],
#        [4.321920e+03],
#        [1.410560e+03],
#        [9.088000e+02],
#        [3.969728e+04],
#        [7.507200e+02],
#        [1.830400e+02],
#        [9.862400e+02],
#        [8.307200e+02],
#        [5.132160e+03],
#        [3.985920e+03],
#        [2.042496e+04],
#        [1.077888e+04],
#        [3.097792e+04],
#        [1.498880e+04],
#        [1.137408e+04],
#        [5.962624e+04],
#        [2.687936e+04],
#        [7.680000e+02],
#        [1.169024e+04],
#        [1.999424e+04],
#        [4.377152e+04],
#        [2.109440e+03],
#        [3.415680e+03],
#        [7.539200e+02],
#        [2.711680e+03],
#        [2.513920e+03],
#        [9.011200e+02],
#        [8.160000e+02],
#        [1.864960e+03],
#        [8.822400e+03],
#        [2.479360e+03],
#        [5.973120e+03],
#        [3.992320e+03],
#        [1.545216e+04],
#        [1.963520e+03],
#        [2.158080e+03],
#        [1.416320e+03],
#        [2.315520e+03],
#        [1.821440e+03],
#        [1.788160e+03],
#        [3.262080e+03],
#        [7.681920e+03],
#        [4.528000e+03],
#        [1.109184e+04],
#        [9.243520e+03],
#        [1.226048e+04],
#        [5.964800e+03],
#        [3.716544e+04],
#        [1.211648e+04],
#        [1.403392e+04],
#        [1.024320e+04],
#        [1.912960e+04],
#        [6.444800e+02],
#        [1.112320e+03],
#        [1.231360e+03],
#        [1.419520e+03],
#        [1.017280e+04],
#        [4.678400e+02],
#        [6.374400e+02],
#        [9.828480e+03],
#        [6.553600e+02],
#        [1.292800e+03],
#        [7.974400e+02],
#        [1.184000e+03],
#        [3.725440e+03],
#        [6.592000e+01],
#        [1.235200e+02],
#        [7.750400e+02],
#        [8.000000e+02],
#        [9.436160e+03],
#        [5.660160e+03],
#        [3.287040e+03],
#        [3.728640e+03],
#        [8.236800e+02],
#        [5.017600e+02],
#        [6.361600e+02],
#        [1.762176e+04],
#        [1.323712e+04],
#        [5.964800e+02],
#        [6.137600e+02],
#        [8.614400e+02],
#        [1.911616e+04],
#        [2.345984e+04],
#        [1.821120e+04],
#        [6.892800e+02],
#        [7.219200e+02],
#        [9.907200e+02],
#        [9.632000e+02],
#        [1.530240e+03],
#        [1.502016e+04],
#        [2.240384e+04],
#        [6.937600e+02],
#        [5.772800e+02],
#        [2.011456e+04],
#        [7.564800e+02],
#        [2.398848e+04],
#        [3.043712e+04],
#        [3.494400e+02],
#        [2.025280e+04],
#        [3.279360e+03],
#        [1.385408e+04],
#        [9.962880e+03],
#        [9.731840e+03],
#        [7.891200e+02],
#        [4.633600e+02],
#        [1.390912e+04],
#        [1.893504e+04],
#        [6.150400e+02],
#        [1.148544e+04],
#        [1.308224e+04],
#        [4.850560e+03],
#        [1.635136e+04],
#        [2.810240e+03],
#        [8.501120e+03],
#        [6.796800e+02],
#        [1.394176e+04],
#        [1.924352e+04],
#        [5.299200e+02],
#        [1.165440e+03],
#        [5.644800e+02],
#        [1.823360e+03],
#        [2.232320e+03],
#        [9.945600e+02],
#        [3.349120e+03],
#        [7.700480e+03],
#        [2.443584e+04],
#        [2.983680e+03],
#        [1.202816e+04],
#        [7.512320e+03],
#        [1.013120e+04],
#        [9.843200e+02],
#        [2.599296e+04],
#        [5.309440e+03],
#        [1.782400e+03],
#        [1.476480e+03],
#        [1.488512e+04],
#        [3.456000e+03],
#        [1.600000e+02],
#        [3.814400e+02],
#        [9.145600e+02],
#        [8.089600e+02],
#        [2.726400e+02],
#        [6.688000e+02],
#        [3.904000e+02],
#        [1.123840e+03],
#        [1.965760e+04],
#        [7.577600e+02],
#        [3.738240e+03],
#        [3.648000e+02],
#        [1.019520e+03],
#        [3.328000e+02],
#        [1.236480e+03],
#        [2.473792e+04],
#        [3.564160e+03],
#        [4.736000e+02],
#        [1.142208e+04],
#        [3.857344e+04],
#        [2.496000e+02],
#        [6.860800e+02],
#        [8.838400e+02],
#        [1.612800e+02],
#        [1.735680e+03],
#        [5.568000e+01],
#        [3.279360e+03],
#        [1.961664e+04],
#        [8.832000e+02],
#        [1.941760e+04],
#        [1.450240e+03],
#        [2.620736e+04],
#        [2.342848e+04],
#        [6.668800e+02],
#        [5.734400e+02],
#        [5.201280e+03],
#        [2.030080e+03],
#        [1.117440e+03],
#        [1.241600e+03],
#        [3.242880e+03],
#        [4.608000e+02],
#        [6.784000e+02],
#        [1.383040e+03],
#        [6.336000e+01],
#        [8.524800e+02],
#        [8.288000e+02],
#        [9.904000e+03],
#        [1.140480e+03],
#        [2.974464e+04],
#        [1.962176e+04],
#        [1.827840e+03],
#        [1.494400e+03],
#        [5.203840e+03],
#        [1.301760e+03],
#        [1.502080e+03],
#        [5.809920e+03],
#        [1.018880e+03],
#        [1.864448e+04],
#        [7.674880e+03],
#        [1.712640e+03],
#        [5.040000e+03],
#        [4.677120e+03],
#        [6.728320e+03],
#        [1.283456e+04],
#        [2.489792e+04],
#        [1.153856e+04],
#        [4.094720e+03],
#        [7.550080e+03],
#        [2.760320e+03],
#        [3.795840e+03],
#        [1.138176e+04],
#        [1.880960e+03],
#        [1.192128e+04],
#        [1.634560e+03],
#        [1.003648e+04],
#        [1.861760e+03],
#        [1.369600e+03],
#        [1.895488e+04],
#        [1.690240e+03],
#        [5.331200e+02],
#        [1.512448e+04],
#        [4.343680e+03],
#        [1.337920e+04],
#        [1.296640e+03],
#        [1.327360e+03],
#        [2.670912e+04],
#        [1.334528e+04],
#        [9.280000e+01],
#        [1.326080e+03],
#        [5.318400e+02],
#        [2.191296e+04],
#        [3.744000e+02],
#        [6.265600e+02],
#        [1.768320e+03],
#        [2.733440e+04],
#        [1.637568e+04],
#        [1.030592e+04],
#        [3.590400e+02],
#        [3.897600e+02],
#        [6.347136e+04],
#        [5.327872e+04],
#        [5.728000e+02],
#        [1.579584e+04],
#        [5.222400e+02],
#        [3.030144e+04],
#        [1.888768e+04],
#        [5.210688e+04],
#        [4.096000e+02],
#        [2.880000e+02],
#        [4.070400e+02],
#        [2.504768e+04],
#        [2.234240e+03],
#        [9.113600e+02],
#        [3.948800e+02],
#        [4.192000e+02],
#        [4.556800e+02],
#        [7.404800e+02],
#        [2.951296e+04],
#        [4.761600e+02],
#        [2.594624e+04],
#        [2.151680e+03],
#        [5.632640e+03],
#        [7.216000e+03],
#        [7.776000e+02],
#        [2.123520e+03],
#        [1.788800e+03],
#        [2.216960e+03],
#        [2.005120e+03],
#        [5.384320e+03],
#        [1.847680e+03],
#        [2.976000e+02],
#        [1.637632e+04],
#        [2.560000e+03],
#        [5.162240e+03],
#        [1.518208e+04],
#        [4.859648e+04],
#        [1.880960e+03],
#        [2.142528e+04],
#        [1.082368e+04],
#        [5.721600e+02],
#        [7.635840e+03],
#        [2.899776e+04],
#        [2.168512e+04],
#        [1.248640e+04],
#        [5.715200e+02],
#        [1.361024e+04],
#        [2.235840e+04],
#        [2.873536e+04],
#        [1.522752e+04],
#        [1.500160e+03],
#        [2.575488e+04],
#        [1.348608e+04],
#        [1.671872e+04],
#        [1.548864e+04],
#        [8.215040e+03],
#        [1.063040e+03],
#        [1.284544e+04],
#        [2.040832e+04],
#        [3.102080e+03],
#        [2.820480e+03],
#        [3.495296e+04],
#        [1.511040e+03],
#        [4.358400e+02],
#        [2.067200e+04],
#        [1.796480e+03],
#        [3.669120e+03],
#        [1.274880e+03],
#        [3.910400e+02],
#        [1.496320e+03],
#        [4.128000e+02],
#        [1.252224e+04],
#        [3.850240e+03],
#        [8.627200e+02],
#        [1.282816e+04],
#        [3.795200e+02],
#        [1.377984e+04],
#        [2.168064e+04],
#        [2.787840e+03],
#        [1.128960e+04],
#        [1.026176e+04],
#        [7.328000e+02],
#        [1.572480e+04],
#        [2.047040e+04],
#        [6.968960e+03],
#        [1.144512e+04],
#        [2.894784e+04],
#        [2.150400e+03],
#        [1.410560e+03],
#        [2.643392e+04],
#        [2.354432e+04],
#        [1.176320e+03],
#        [1.723136e+04],
#        [3.795200e+02],
#        [4.326080e+04],
#        [1.546944e+04],
#        [4.272640e+04],
#        [3.980800e+03],
#        [2.734720e+03],
#        [3.094400e+03],
#        [7.884160e+03],
#        [8.576000e+02],
#        [4.160000e+02],
#        [1.770880e+03],
#        [1.374080e+03],
#        [6.840320e+03],
#        [2.557440e+03],
#        [2.360320e+03],
#        [3.813760e+03],
#        [2.493440e+03],
#        [1.686400e+03],
#        [7.840000e+02],
#        [5.773440e+03],
#        [3.836160e+03],
#        [1.889920e+03],
#        [4.303360e+03],
#        [1.158400e+02],
#        [1.279488e+04],
#        [1.075840e+03],
#        [9.273600e+02],
#        [1.912768e+04],
#        [6.506304e+04],
#        [1.511872e+04],
#        [1.366144e+04],
#        [2.311680e+03],
#        [2.401600e+04],
#        [1.520000e+04],
#        [1.157504e+04],
#        [1.269120e+04],
#        [1.582336e+04],
#        [7.466880e+03],
#        [4.682240e+03],
#        [2.853248e+04],
#        [3.813760e+03],
#        [2.042240e+03],
#        [8.556800e+03],
#        [1.257600e+03],
#        [1.149504e+04],
#        [1.751424e+04],
#        [6.572800e+04]])

# %%
y
# Out:
# array([[3.90772836e+02],
#        [9.41670537e+02],
#        [3.11617063e+03],
#        [3.09927139e+02],
#        [2.77944357e+03],
#        [3.89298571e+03],
#        [1.35322249e+02],
#        [5.79085958e+03],
#        [2.27988277e+04],
#        [7.41436909e+02],
#        [4.79214532e+03],
#        [9.34507676e+03],
#        [5.05116921e+02],
#        [1.14286951e+01],
#        [7.57582960e+01],
#        [1.04638448e+04],
#        [4.06039219e+02],
#        [2.65464682e+02],
#        [1.38039041e+03],
#        [1.27528828e+02],
#        [1.18319566e+02],
#        [1.16132984e+03],
#        [2.17481640e+02],
#        [2.46987623e+03],
#        [8.91278695e+01],
#        [1.35490300e+01],
#        [1.17563134e+01],
#        [1.18617362e+01],
#        [2.41594711e+02],
#        [1.01239166e+02],
#        [1.73192614e+02],
#        [4.11248606e+01],
#        [3.70529913e+01],
#        [1.18498903e+02],
#        [4.40271427e+01],
#        [2.80149021e+01],
#        [2.32560520e+02],
#        [2.94762262e+02],
#        [2.32749384e+02],
#        [6.17127224e+00],
#        [2.41382272e+02],
#        [5.66197993e+02],
#        [6.85377400e+01],
#        [1.38768113e+02],
#        [1.29720307e+02],
#        [1.15811166e+02],
#        [0.00000000e+00],
#        [1.18883298e+02],
#        [1.25681764e+02],
#        [3.30807676e+01],
#        [3.01483249e+02],
#        [6.15190512e+01],
#        [3.59893372e+01],
#        [5.18360781e+02],
#        [8.35486364e+03],
#        [2.27099670e+01],
#        [7.75263236e+00],
#        [4.26942220e+01],
#        [4.56391559e+00],
#        [1.01897628e+02],
#        [3.41948062e+01],
#        [9.97231627e+00],
#        [3.47951009e+02],
#        [1.68238934e+03],
#        [9.19825515e+01],
#        [1.36926329e+02],
#        [8.48355480e+01],
#        [6.18725178e+02],
#        [1.26156162e+02],
#        [3.33460236e+02],
#        [6.83020327e+01],
#        [1.26702748e+02],
#        [2.72618000e+02],
#        [1.46259878e+02],
#        [2.18297384e+02],
#        [7.10211179e+01],
#        [2.53745727e+02],
#        [4.88558501e+01],
#        [9.12048461e+01],
#        [3.07267666e+01],
#        [4.99395324e+00],
#        [7.32561892e+02],
#        [6.69681633e+02],
#        [0.00000000e+00],
#        [6.89322210e+01],
#        [4.99298414e+01],
#        [2.80598775e+01],
#        [2.29198752e+03],
#        [1.39948493e+02],
#        [9.37963348e+01],
#        [1.20226288e+01],
#        [1.51570642e+02],
#        [2.22182925e+04],
#        [0.00000000e+00],
#        [1.20523763e+02],
#        [8.67418564e+02],
#        [6.00767617e+02],
#        [5.86002701e+02],
#        [2.28323230e+02],
#        [2.53975795e+02],
#        [2.86672498e+02],
#        [7.09916870e+02],
#        [1.05813708e+03],
#        [1.18966414e+02],
#        [3.71762097e+03],
#        [6.20483886e+00],
#        [2.00562821e+02],
#        [7.84830778e+02],
#        [3.96213938e+02],
#        [1.05276453e+02],
#        [0.00000000e+00],
#        [5.52910590e+03],
#        [6.83259780e+02],
#        [1.55938742e+02],
#        [1.50479029e+03],
#        [2.95816991e+01],
#        [1.77396041e+02],
#        [2.05707520e+02],
#        [6.10749494e+01],
#        [1.09495005e+04],
#        [9.20332783e+01],
#        [1.71142429e+01],
#        [1.75626554e+04],
#        [3.45528970e+03],
#        [1.55513906e+04],
#        [7.40619828e+03],
#        [1.30302626e+03],
#        [4.50316326e+02],
#        [4.03971780e+04],
#        [2.08741333e+01],
#        [2.13528970e+01],
#        [0.00000000e+00],
#        [3.70475934e+00],
#        [5.90449497e+01],
#        [2.25069594e+02],
#        [3.15682757e+01],
#        [2.89329995e+01],
#        [4.77295341e+02],
#        [1.46989280e+03],
#        [1.97825870e+01],
#        [2.50822057e+02],
#        [1.18775297e+02],
#        [1.73871542e+02],
#        [6.60026977e+01],
#        [8.63188785e+02],
#        [7.73291277e+01],
#        [2.07808861e+02],
#        [2.09802400e+02],
#        [0.00000000e+00],
#        [1.35066887e+01],
#        [3.32538476e+01],
#        [2.75595673e+02],
#        [7.56587857e+00],
#        [9.30156546e+00],
#        [2.17666580e+01],
#        [4.82453721e+01],
#        [5.30227089e+02],
#        [4.03449795e+02],
#        [0.00000000e+00],
#        [8.98770918e+01],
#        [3.97008538e+01],
#        [7.13125423e+01],
#        [0.00000000e+00],
#        [5.90270112e+02],
#        [1.42889075e+04],
#        [8.77060182e+03],
#        [5.95724802e+00],
#        [1.90083701e+03],
#        [8.65131187e+02],
#        [3.58108256e+01],
#        [1.95283282e+04],
#        [5.90815659e+03],
#        [1.77957177e+04],
#        [2.01293796e+02],
#        [1.95821094e+03],
#        [6.64751013e+02],
#        [1.92771607e+02],
#        [1.80975960e+04],
#        [2.10825157e+01],
#        [1.46924600e-01],
#        [1.09116692e+02],
#        [1.51221594e+02],
#        [4.01023119e+02],
#        [4.42364534e+02],
#        [9.21118467e+03],
#        [1.63416235e+02],
#        [2.38143377e+04],
#        [7.22743361e+02],
#        [4.82665743e+02],
#        [3.28715908e+04],
#        [9.18804869e+03],
#        [0.00000000e+00],
#        [1.88356050e+03],
#        [5.06705890e+02],
#        [7.28214113e+03],
#        [2.20636919e+02],
#        [2.15516257e+02],
#        [3.38589626e+01],
#        [5.03783578e+02],
#        [4.85413763e+01],
#        [1.75791072e+01],
#        [2.85076077e+01],
#        [5.66092014e+01],
#        [2.04515595e+03],
#        [5.42192848e+02],
#        [1.74783770e+03],
#        [2.89809781e+02],
#        [8.64597375e+02],
#        [9.76093386e+01],
#        [1.35942028e+02],
#        [6.53179662e+01],
#        [4.72126845e+02],
#        [9.40757225e+01],
#        [2.33962593e+02],
#        [6.13040017e+02],
#        [1.40598414e+03],
#        [1.53176578e+03],
#        [4.73449757e+02],
#        [3.75248154e+02],
#        [1.19458628e+02],
#        [1.23516995e+03],
#        [1.14456101e+03],
#        [2.61669799e+02],
#        [4.49775205e+02],
#        [1.01479685e+03],
#        [8.78924663e+03],
#        [3.81302825e+01],
#        [3.72707827e+01],
#        [2.15335791e+01],
#        [9.48141146e+01],
#        [1.80464810e+02],
#        [1.88765565e+01],
#        [1.32159933e+02],
#        [4.48387386e+02],
#        [6.65503298e+01],
#        [1.40958836e+02],
#        [2.78331949e+01],
#        [8.94508264e+02],
#        [2.16876969e+02],
#        [6.25933320e-01],
#        [1.33299029e+00],
#        [3.87120271e+01],
#        [1.03452617e+02],
#        [1.69956920e+03],
#        [1.17828521e+03],
#        [2.02378468e+02],
#        [6.69777629e+02],
#        [2.32855494e+01],
#        [3.52648061e+01],
#        [3.74453039e+01],
#        [1.12980874e+03],
#        [2.57812655e+03],
#        [1.34422976e+02],
#        [7.57069810e+01],
#        [2.22557588e+02],
#        [6.19761165e+03],
#        [2.54282992e+03],
#        [2.36260617e+03],
#        [2.14473292e+01],
#        [2.03359338e+02],
#        [1.02328083e+02],
#        [4.56002603e+01],
#        [5.50860398e+02],
#        [2.16435478e+03],
#        [2.12862550e+03],
#        [7.62042895e+01],
#        [1.99649597e+01],
#        [4.82878449e+03],
#        [1.39755390e+02],
#        [2.52686975e+03],
#        [3.67959105e+03],
#        [1.33968495e+02],
#        [1.77427956e+03],
#        [4.90739411e+00],
#        [2.16070079e+03],
#        [1.36006835e+03],
#        [6.33317669e+02],
#        [1.11064497e+00],
#        [2.19226815e+01],
#        [5.37338922e+02],
#        [1.11701118e+04],
#        [8.74149497e+00],
#        [1.63425552e+03],
#        [2.24098138e+03],
#        [4.31906584e+02],
#        [4.84334651e+03],
#        [1.38369450e+02],
#        [3.09433181e+02],
#        [1.01301545e+01],
#        [2.74845185e+03],
#        [1.97488966e+03],
#        [1.95553080e+02],
#        [1.59229499e+02],
#        [1.73052504e+01],
#        [9.61250645e+01],
#        [1.86418222e+02],
#        [7.25504202e+01],
#        [3.06029159e+02],
#        [7.88318283e+02],
#        [5.60588624e+03],
#        [1.18537271e+02],
#        [1.19462448e+03],
#        [1.61707721e+03],
#        [8.63076983e+02],
#        [4.15684186e+01],
#        [4.46592046e+03],
#        [3.29234175e+02],
#        [2.27793035e+02],
#        [1.10176359e+02],
#        [7.89238320e+02],
#        [6.32434504e+02],
#        [1.55918345e+01],
#        [6.74636141e+01],
#        [1.11491721e+02],
#        [7.31720263e+01],
#        [2.97792497e+01],
#        [7.13366943e+01],
#        [6.83990247e+01],
#        [3.45261737e+01],
#        [1.96496920e+03],
#        [9.06646927e+00],
#        [2.35891713e+02],
#        [1.85745653e+01],
#        [9.50723128e+01],
#        [0.00000000e+00],
#        [1.18597135e+01],
#        [7.90510922e+03],
#        [4.40976987e+02],
#        [3.43449484e+01],
#        [1.72372619e+03],
#        [6.02235658e+03],
#        [0.00000000e+00],
#        [3.99718773e+01],
#        [3.76458052e+01],
#        [1.16374419e+01],
#        [1.04965861e+02],
#        [6.01543658e+00],
#        [1.60443002e+02],
#        [2.17053891e+03],
#        [1.43405723e+02],
#        [2.35763958e+03],
#        [1.57661999e+02],
#        [3.97168350e+03],
#        [5.32556791e+03],
#        [7.09453922e+00],
#        [4.90576319e+00],
#        [6.14334688e+02],
#        [1.71375856e+02],
#        [4.11924235e+01],
#        [5.63032489e+02],
#        [1.73406045e+02],
#        [3.71537051e+00],
#        [6.48952379e+01],
#        [1.01954977e+02],
#        [2.26108057e+00],
#        [2.00930143e+02],
#        [3.33844457e+01],
#        [6.83685645e+02],
#        [3.19301168e+02],
#        [6.72331288e+03],
#        [4.34120359e+03],
#        [7.59196386e+01],
#        [1.08546117e+02],
#        [1.25286929e+03],
#        [4.79021992e+01],
#        [1.85383490e+02],
#        [1.09358769e+03],
#        [1.59995309e+02],
#        [6.75617715e+03],
#        [1.54531723e+03],
#        [1.84937343e+02],
#        [1.04045831e+03],
#        [4.97652652e+02],
#        [8.71208299e+02],
#        [9.99290458e+02],
#        [1.10020241e+04],
#        [4.21589147e+03],
#        [1.40405785e+03],
#        [1.29225623e+03],
#        [2.46243638e+02],
#        [2.88785572e+02],
#        [2.64932990e+03],
#        [4.99089572e+02],
#        [2.74597414e+03],
#        [1.29798667e+02],
#        [2.04231924e+03],
#        [2.05097835e+02],
#        [1.95188346e+02],
#        [6.53866965e+03],
#        [1.92274765e+01],
#        [1.06237388e+02],
#        [3.76386282e+03],
#        [7.77714141e+02],
#        [2.53149732e+03],
#        [1.91228065e+01],
#        [3.72403434e+01],
#        [9.48247390e+03],
#        [3.35440772e+03],
#        [1.09368202e+01],
#        [2.17266270e+02],
#        [1.08708350e+02],
#        [8.96972747e+03],
#        [2.56476706e+01],
#        [4.03924586e+01],
#        [4.93379368e+02],
#        [1.31251941e+04],
#        [1.95481596e+03],
#        [2.58930955e+03],
#        [2.68999552e+01],
#        [2.29368516e+01],
#        [1.92289354e+04],
#        [3.16822316e+04],
#        [5.20070976e+00],
#        [1.66742978e+03],
#        [9.57690329e+01],
#        [1.88391001e+04],
#        [9.96547805e+02],
#        [2.32228936e+04],
#        [0.00000000e+00],
#        [8.46939120e-01],
#        [2.19820397e+01],
#        [2.13382413e+03],
#        [7.71104878e+01],
#        [7.12455667e+01],
#        [8.28789181e+01],
#        [5.94342473e+01],
#        [1.31493868e+01],
#        [1.26418300e+02],
#        [1.14869960e+04],
#        [3.72473758e+00],
#        [3.04566569e+03],
#        [9.93375791e+01],
#        [2.36735186e+03],
#        [2.24590952e+02],
#        [4.54519645e+00],
#        [1.13251742e+02],
#        [5.79930792e+01],
#        [2.36507901e+02],
#        [9.71626896e+01],
#        [3.11180786e+02],
#        [3.85461341e+02],
#        [5.76023402e+00],
#        [7.46105994e+03],
#        [1.15097547e+02],
#        [1.47499758e+03],
#        [2.35495126e+03],
#        [2.38510829e+04],
#        [4.12981142e+02],
#        [2.28233331e+03],
#        [2.48294642e+02],
#        [3.62061106e+01],
#        [1.53340083e+03],
#        [1.01163918e+04],
#        [2.12151147e+03],
#        [4.12185361e+02],
#        [4.72254727e+00],
#        [2.98123996e+02],
#        [1.20302264e+03],
#        [5.10863332e+03],
#        [1.95493031e+03],
#        [1.48247451e+02],
#        [1.04574074e+02],
#        [1.65070761e+02],
#        [1.74548557e+03],
#        [2.53985285e+03],
#        [5.06251856e+02],
#        [9.50061138e+01],
#        [1.94082243e+03],
#        [3.02608985e+03],
#        [2.99552714e+02],
#        [1.52640346e+02],
#        [7.67030248e+03],
#        [2.61488198e+02],
#        [1.35008922e+02],
#        [3.80294449e+03],
#        [1.31536534e+02],
#        [3.42963915e+02],
#        [6.96807343e+01],
#        [1.22118911e+02],
#        [1.22607557e+02],
#        [8.07969871e+01],
#        [1.08675592e+03],
#        [9.95452012e+01],
#        [3.71642008e+02],
#        [2.46066332e+03],
#        [7.16401224e+00],
#        [4.96549012e+03],
#        [4.21301255e+03],
#        [2.96698038e+02],
#        [2.32353558e+03],
#        [1.37705191e+03],
#        [4.31950645e+01],
#        [4.28578297e+03],
#        [5.23026704e+03],
#        [1.09283298e+03],
#        [8.95620992e+02],
#        [1.67172701e+04],
#        [2.95781946e+02],
#        [4.64836601e+02],
#        [1.36820992e+04],
#        [5.46472246e+03],
#        [2.12814195e+02],
#        [6.40227073e+03],
#        [2.37355964e+01],
#        [1.50598311e+04],
#        [9.61359568e+02],
#        [4.93148013e+03],
#        [5.75111323e+02],
#        [5.69353781e+02],
#        [4.11753460e+02],
#        [1.72726273e+02],
#        [2.45228102e+01],
#        [2.70785610e+01],
#        [1.56576546e+02],
#        [2.66194197e+02],
#        [2.06979949e+02],
#        [9.63189550e+02],
#        [2.93147471e+02],
#        [2.58749912e+02],
#        [2.28163807e+02],
#        [2.18762886e+02],
#        [3.14085051e+01],
#        [1.22368055e+03],
#        [4.41803214e+02],
#        [4.39760676e+01],
#        [2.76369839e+02],
#        [2.71128017e+00],
#        [5.71950001e+03],
#        [7.11137563e+01],
#        [9.02717966e+01],
#        [2.76234583e+03],
#        [5.95492330e+04],
#        [2.60585226e+03],
#        [1.50470938e+03],
#        [5.14345068e+02],
#        [8.18889109e+03],
#        [1.77324756e+03],
#        [1.67020371e+03],
#        [1.46296377e+03],
#        [2.76414290e+03],
#        [2.10795052e+03],
#        [4.75133035e+02],
#        [3.04911158e+03],
#        [1.42303562e+03],
#        [1.14656800e+02],
#        [6.25720258e+02],
#        [1.32960602e+02],
#        [4.14853731e+03],
#        [2.71206255e+03],
#        [5.35227361e+04]])

# %%
# Split data into a training set and a test set using the train_test_split function

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# #I decided to try it on the municipal data to see what difference it made

# %%
# Create a regression object for the training set

regression = LinearRegression()

# %%
# Fit the regression object onto the training set.

regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y using X.

y_predicted = regression.predict(X_test)

# %%
# Create a plot that shows the regression line from the model on the test set.

plot_test = plt
plot_test.scatter(X_test, y_test, color='gray', s = 15)
plot_test.plot(X_test, y_predicted, color='red', linewidth =3)
plot_test.title('County Acreage vs Total Acres of Open Space in the County (Test set)')
plot_test.xlabel('Total Acres')
plot_test.ylabel('Acres of Preserved Open Space')
plot_test.show()

# %%
# Create objects that contain the model summary statistics.

rmse = mean_squared_error(y_test, y_predicted) # This is the mean squared error
r2 = r2_score(y_test, y_predicted) # This is the R2 score.

# %%
# Print the model summary statistics and evaluate the model

print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.40977379]]
# Mean squared error:  13874312.35986935
# R2 score:  0.5637699005013436

# %%
y_predicted
# Out:
# array([[ -698.58110916],
#        [-1113.20661662],
#        [ -439.21069368],
#        [17185.12705316],
#        [ -292.61002406],
#        [ -677.60069132],
#        [ 4962.46013309],
#        [ -822.10331916],
#        [ -114.53872769],
#        [ 1567.82852744],
#        [ -286.31589871],
#        [ -916.51519942],
#        [ -910.22107407],
#        [ -817.64498037],
#        [ 6820.01387714],
#        [ -954.0176963 ],
#        [ 9318.51938603],
#        [ 2933.39147325],
#        [ 3445.31366842],
#        [  896.1929015 ],
#        [-1064.68940037],
#        [ 8412.68984601],
#        [-1040.03740942],
#        [ -472.25485177],
#        [-1169.59148955],
#        [14571.22924617],
#        [16273.00338779],
#        [ -738.70615827],
#        [ 4919.71253176],
#        [ 3896.13039664],
#        [-1070.7212705 ],
#        [-1056.55948846],
#        [ -657.14478394],
#        [   40.97861951],
#        [ -494.54654572],
#        [13822.75283992],
#        [ 4007.85112161],
#        [  111.78752971],
#        [13549.48289762],
#        [ -499.00488451],
#        [ 2752.69762465],
#        [   35.99577028],
#        [  265.20683512],
#        [13087.65145004],
#        [ 9779.30181272],
#        [-1079.63794808],
#        [ 4021.48839321],
#        [ -751.03215375],
#        [ 4986.06310316],
#        [-1161.72383286],
#        [  681.40587392],
#        [11458.78426039],
#        [ -403.28172814],
#        [ 7153.07801026],
#        [  544.77090277],
#        [ 6603.65331822],
#        [ -186.13440355],
#        [25698.45610004],
#        [ -413.50968183],
#        [-1000.17461553],
#        [ 9596.77217756],
#        [ -653.47321081],
#        [ 2142.95423133],
#        [ -349.78166266],
#        [ 3391.02683727],
#        [ -833.90480419],
#        [  267.56713213],
#        [ -691.23796292],
#        [ 1865.22595024],
#        [  461.6359971 ],
#        [ 7235.68840549],
#        [ 3788.86801046],
#        [ -469.63229954],
#        [ -788.01014018],
#        [ -975.26036935],
#        [-1123.43457031],
#        [ -529.16423514],
#        [-1208.14300732],
#        [ 1212.47270036],
#        [10626.91069325],
#        [ -470.94357565],
#        [ -670.78205553],
#        [-1078.85118241],
#        [ -619.64228706],
#        [ -502.4142024 ],
#        [  683.5039157 ],
#        [ -719.82378222],
#        [ 8778.01137156],
#        [ 7063.91123446],
#        [-1209.19202821],
#        [ -925.16962177],
#        [ -978.40743203],
#        [24773.74418398],
#        [  528.24882373],
#        [ -657.14478394],
#        [  752.47703933],
#        [ 2877.53111077],
#        [  880.1953329 ],
#        [ 1586.71090349],
#        [ -897.63282337],
#        [ -235.70064068],
#        [ -820.52978782],
#        [ 1920.29954706],
#        [ -712.7428912 ],
#        [  971.19789526],
#        [ 2631.53571166],
#        [ 3181.74716937],
#        [ -972.11330668],
#        [ 1072.95292176],
#        [10456.70705356],
#        [-1080.42471375],
#        [ -697.26983304],
#        [ 3475.21076384],
#        [ 5465.20339546],
#        [-1046.33153477],
#        [ -724.01986578],
#        [ -934.87306502],
#        [ -319.62231202],
#        [  292.74363353],
#        [-1160.15030152],
#        [ -104.04851877],
#        [ 1858.66956967],
#        [22018.49081183],
#        [  327.62357818],
#        [ 2627.60188331],
#        [-1079.63794808],
#        [ -924.64511133],
#        [ -860.39258171],
#        [-1184.54003726],
#        [ -602.85795279],
#        [-1088.03011522],
#        [ 1642.8335212 ],
#        [-1017.22120502],
#        [-1073.34382273],
#        [ 2792.29816332],
#        [ -187.18342444],
#        [-1000.43687076],
#        [ 1104.42354851],
#        [ 5985.78001298],
#        [16348.27063678],
#        [  320.28043194],
#        [ 5103.81569826],
#        [ -855.14747725],
#        [ 4993.4062494 ],
#        [ -983.12802604],
#        [  503.59683277],
#        [ 2298.99608898],
#        [ 1145.59761851],
#        [ 5424.02932546],
#        [ -691.76247336],
#        [-1043.44672732],
#        [ -779.0934626 ],
#        [ -616.7574796 ],
#        [ 6721.66816854],
#        [-1045.28251388],
#        [ -883.73329655],
#        [ 3471.27693549],
#        [ -823.15234005],
#        [ 4784.65109195],
#        [ -583.71332151],
#        [ 1610.57612877],
#        [12765.8642915 ],
#        [ 2823.24427962],
#        [-1085.66981821],
#        [ -502.15194718]])

# %%
# Create a dataframe comparing the actual & predicted values of y

data = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_predicted.flatten()})
data.head(30)
# Out:
#           Actual     Predicted
# 0      49.929841   -698.581109
# 1       5.760234  -1113.206617
# 2     600.767617   -439.210694
# 3   17795.717700  17185.127053
# 4     225.069594   -292.610024
# 5     294.762262   -677.600691
# 6    3763.862818   4962.460133
# 7      12.022629   -822.103319
# 8     569.353781   -114.538728
# 9     206.979949   1567.828527
# 10    472.126845   -286.315899
# 11      4.545196   -916.515199
# 12     84.835548   -910.221074
# 13    159.995309   -817.644980
# 14   1964.969204   6820.013877
# 15     39.971877   -954.017696
# 16    104.574074   9318.519386
# 17    180.464810   2933.391473
# 18   1723.726186   3445.313668
# 19    614.334688    896.192902
# 20     27.078561  -1064.689400
# 21   5464.722461   8412.689846
# 22      3.724738  -1040.037409
# 23    205.097835   -472.254852
# 24     15.591834  -1169.591490
# 25   6022.356584  14571.229246
# 26   4931.480129  16273.003388
# 27    250.822057   -738.706158
# 28   2164.354785   4919.712532
# 29   1086.755917   3896.130397

# %%
# Predict y

y_predicted_train = regression.predict(X_train)

# %%
rmse = mean_squared_error(y_train, y_predicted_train)
r2 = r2_score(y_train, y_predicted_train)

# %%
#Check the model statistics for MSE and R2

print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.40977379]]
# Mean squared error:  9588608.141504338
# R2 score:  0.6810652453482738

# %%
# Visualizing the test set results.

plot_test = plt
plot_test.scatter(X_train, y_train, color='green', s = 15)
plot_test.plot(X_train, y_predicted_train, color='red', linewidth =3)
plot_test.title('County Acreage vs Total Acres of Open Space in the County (Training set)')
plot_test.xlabel('Total Acres')
plot_test.ylabel('Acres of Preserved Open Space')
plot_test.show()

# %% [markdown]
# #This algorithim was much more accurate than the county level data and shows the greater amount of variation in the data. The regression line shows a positive correlation and the data is clustered around the line. The other dataset didn't include the outliers in the high range like this one does since it has more data points. Definitely shows why having a larger data set can make a difference in accuracy of the model.
